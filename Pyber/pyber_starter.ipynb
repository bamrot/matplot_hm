# %% [markdown]
# ## Pyber Home work

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv("data/city_data.csv")
ride_data = pd.read_csv("data/ride_data.csv")

# Combine the data into a single dataset
city_ride = city_data.merge(ride_data, on = "city")

# Display the data table for preview
city_ride.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %% [markdown]
# Calculating
#
# Average Fare ($) Per City
# Total Number of Rides Per City
# Total Number of Drivers Per City
# City Type (Urban, Suburban, Rural)

# %%
#groupby per city
city_fare = city_ride.groupby('city')
city_fare.head()
# Out:
#                    city  driver_count   type                 date   fare  \
# 0           Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1           Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2           Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3           Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4           Richardfort            38  Urban  2018-04-17 02:26:37  23.00
# 28         Williamsstad            59  Urban  2018-01-23 17:51:24  19.62
# 29         Williamsstad            59  Urban  2018-03-29 21:43:04  35.58
# 30         Williamsstad            59  Urban  2018-02-13 20:07:49  33.72
# 31         Williamsstad            59  Urban  2018-05-01 01:26:21  26.81
# 32         Williamsstad            59  Urban  2018-02-23 17:42:40   4.68
# 51          Port Angela            67  Urban  2018-04-17 06:23:18  16.34
# 52          Port Angela            67  Urban  2018-03-31 15:22:26  30.77
# ...

# %%
# average fare per city
city_average = city_fare["fare"].mean()
city_average.head()
# Out:
# city
# Amandaburgh      24.641667
# Barajasview      25.332273
# Barronchester    36.422500
# Bethanyland      32.956111
# Bradshawfurt     40.064000
# Name: fare, dtype: float64

# %%
# total rides per city
ride_count = city_fare["ride_id"].count()
ride_count.head()
# Out:
# city
# Amandaburgh      18
# Barajasview      22
# Barronchester    16
# Bethanyland      18
# Bradshawfurt     10
# Name: ride_id, dtype: int64

# %%
driver_data = city_data[['city','driver_count']]
driver_data.head()
# Out:
#            city  driver_count
# 0   Richardfort            38
# 1  Williamsstad            59
# 2   Port Angela            67
# 3    Rodneyfort            34
# 4   West Robert            39

# %%
driver_data.driver_count.dtype
# Out:
# dtype('int64')

# %%
#city type grouping
city_type = city_ride.groupby('type')
city_type.head()
# Out:
#                 city  driver_count      type                 date   fare  \
# 0        Richardfort            38     Urban  2018-02-24 08:40:38  13.93
# 1        Richardfort            38     Urban  2018-02-13 12:46:07  14.00
# 2        Richardfort            38     Urban  2018-02-16 13:52:19  17.92
# 3        Richardfort            38     Urban  2018-02-01 20:18:28  10.26
# 4        Richardfort            38     Urban  2018-04-17 02:26:37  23.00
# 1625      Port Shane             7  Suburban  2018-04-09 15:34:40  27.66
# 1626      Port Shane             7  Suburban  2018-04-23 16:05:47  42.26
# 1627      Port Shane             7  Suburban  2018-03-02 12:06:00  14.95
# 1628      Port Shane             7  Suburban  2018-03-26 04:33:30  19.03
# 1629      Port Shane             7  Suburban  2018-03-15 12:09:42  31.58
# 2250  South Jennifer             7     Rural  2018-04-01 09:32:45  21.63
# 2251  South Jennifer             7     Rural  2018-03-07 19:10:13  48.79
# ...

# %%
# select needed columns
driver_count = city_type[['type','city','driver_count']]

driver_count.head()
# Out:
#           type            city  driver_count
# 0        Urban     Richardfort            38
# 1        Urban     Richardfort            38
# 2        Urban     Richardfort            38
# 3        Urban     Richardfort            38
# 4        Urban     Richardfort            38
# 1625  Suburban      Port Shane             7
# 1626  Suburban      Port Shane             7
# 1627  Suburban      Port Shane             7
# 1628  Suburban      Port Shane             7
# 1629  Suburban      Port Shane             7
# 2250     Rural  South Jennifer             7
# 2251     Rural  South Jennifer             7
# 2252     Rural  South Jennifer             7
# 2253     Rural  South Jennifer             7
# 2254     Rural  South Jennifer             7

# %%
city_data
# Out:
#                      city  driver_count      type
# 0             Richardfort            38     Urban
# 1            Williamsstad            59     Urban
# 2             Port Angela            67     Urban
# 3              Rodneyfort            34     Urban
# 4             West Robert            39     Urban
# 5            West Anthony            70     Urban
# 6             West Angela            48     Urban
# 7           Martinezhaven            25     Urban
# 8               Karenberg            22     Urban
# 9             Barajasview            26     Urban
# 10             Robertport            12     Urban
# 11           Joneschester            39     Urban
# 12                Leahton            17     Urban
# 13   West Christopherberg            32     Urban
# 14                Johnton            27     Urban
# 15           Reynoldsfurt            67     Urban
# 16             Port David             7     Urban
# 17    New Kimberlyborough            33     Urban
# ...

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types


# Build the scatter plots for each city types
#state_and_inches.plot(kind="bar", figsize=(20,3))
#ridesharing_data.plot(kind="scatter", x="city_type", y="city_average", grid=True, figsize=(20,10),
              #title="ride per city")
# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
#total fare by city type
cityfare_chart = city_ride.groupby('type')
city_fare.head()
# Out:
#                    city  driver_count   type                 date   fare  \
# 0           Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1           Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2           Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3           Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4           Richardfort            38  Urban  2018-04-17 02:26:37  23.00
# 28         Williamsstad            59  Urban  2018-01-23 17:51:24  19.62
# 29         Williamsstad            59  Urban  2018-03-29 21:43:04  35.58
# 30         Williamsstad            59  Urban  2018-02-13 20:07:49  33.72
# 31         Williamsstad            59  Urban  2018-05-01 01:26:21  26.81
# 32         Williamsstad            59  Urban  2018-02-23 17:42:40   4.68
# 51          Port Angela            67  Urban  2018-04-17 06:23:18  16.34
# 52          Port Angela            67  Urban  2018-03-31 15:22:26  30.77
# ...

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
cityfare_chart_gb_type = city_ride.groupby('type')
cityfare_chart_gb_city = city_ride.groupby('city')
group_type_col_fare_sum = cityfare_chart_gb_city["fare"].sum()
group_type_col_fare_mean = cityfare_chart_gb_city["fare"].mean()
group_type_col_fare_desc = cityfare_chart_gb_city["fare"].describe()
group_type_col_driver_count_sum = cityfare_chart["driver_count"].sum()
group_type_col_fare_desc
# Out:
#                       count       mean        std    min      25%     50%  \
# city
# Amandaburgh            18.0  24.641667  11.496883   6.27  14.9800  24.920
# Barajasview            22.0  25.332273  10.299267   9.21  17.6625  25.545
# Barronchester          16.0  36.422500   7.386021  21.95  30.3650  36.310
# Bethanyland            18.0  32.956111   9.021466  13.86  25.2000  35.735
# Bradshawfurt           10.0  40.064000  16.112780  19.07  23.4975  43.375
# Brandonfort            19.0  35.437368  10.990626  17.50  24.8200  37.350
# Carriemouth            27.0  28.314444  10.620933   8.28  22.3250  27.840
# Christopherfurt        27.0  24.501852  10.980099   6.32  15.5400  24.470
# Colemanland            22.0  30.894545  11.830867  12.62  21.4850  32.065
# Davidfurt              17.0  31.995882  12.234695  13.05  21.2900  28.690
# Deanville              19.0  25.842632  12.000238   4.56  21.3600  25.390
# East Aaronbury          9.0  25.661111   6.926502  16.90  20.5900  23.020
# ...

# %%
ride_pertype = cityfare_chart[['type','ride_id']].count()
ride_pertype.head()
# Out:
#           type  ride_id
# type
# Rural      125      125
# Suburban   625      625
# Urban     1625     1625

# %%
# Build Pie Chart
plt.pie(ride_pertype["ride_id"],
        autopct="%1.1f%%", shadow=True, startangle=140)
# Save Figure
plt.axis("equal")
# Save an image of our chart and print the final product to the screen
plt.savefig("../Images/Pyber.png")
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
driverdata_chart = city_data[['type','driver_count']]
driverdata_chart.head()
# Out:
#     type  driver_count
# 0  Urban            38
# 1  Urban            59
# 2  Urban            67
# 3  Urban            34
# 4  Urban            39

# %%
# Build Pie Charts
citydriver = driverdata_chart.groupby('type')
citydriver.head()
# Out:
#          type  driver_count
# 0       Urban            38
# 1       Urban            59
# 2       Urban            67
# 3       Urban            34
# 4       Urban            39
# 66   Suburban             7
# 67   Suburban             3
# 68   Suburban            23
# 69   Suburban            23
# 70   Suburban            17
# 102     Rural             7
# 103     Rural             4
# 104     Rural             1
# 105     Rural             8
# 106     Rural             6

# %%
#selecting chart data
citydriver_chart = citydriver["driver_count"].sum()
citydriver_chart
# Save Figure
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
city_type = ["Rural","Suburban","Urban"]
drivers = [78,490,2405]
colors = ["yellow","green","lightblue"]
explode = (0.1,0,0)
# Tell matplotlib to create a pie chart based upon the above data
plt.pie(drivers, explode=explode, labels=city_type, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Create axes which are equal so we have a perfect circle
plt.axis("equal")
# Save an image of our chart and print the final product to the screen
plt.savefig("../Images/Pyber2.png")
plt.show()
